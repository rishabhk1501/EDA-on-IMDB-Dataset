# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabhk1501/EDA-on-IMDB-Dataset/blob/main/EDA_on_IMDB_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Exploration

# %%
#Import package
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
working_dir_path = '/content/drive/MyDrive/Datasets'
imdb_df = pd.read_csv(working_dir_path + '/imdb_data.csv')

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
# We can see some columns such as crew contains complicated data structures, let's see the type of these objects
imdb_df.loc[0,'crew']
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
type(imdb_df.loc[0,'crew'])
# Out:
# str

# %% [markdown]
# #Converting the string values to proper lists

# %%
# Lets keep only the columns which are required in analysis

# %%
imdb_df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
columns_to_keep = ['budget', 'genres', 'imdb_id', 'original_language', 'original_title', 'cast', 'crew', 'revenue']

# %%
imdb_df = imdb_df[columns_to_keep]

# %%
imdb_df.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             3000 non-null   int64
#  1   genres             2993 non-null   object
#  2   imdb_id            3000 non-null   object
#  3   original_language  3000 non-null   object
#  4   original_title     3000 non-null   object
#  5   cast               2987 non-null   object
#  6   crew               2984 non-null   object
#  7   revenue            3000 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 187.6+ KB

# %%
def convert_string_to_list(str):
  return eval(str)

# %%
# We will Apply the above function to three columns: genres, cast and crew. Since these columns have null values, we will get rid of null values
imdb_df.loc[~imdb_df['genres'].isna(), 'genres'] = imdb_df.loc[~imdb_df['genres'].isna(), 'genres'].apply(convert_string_to_list)
imdb_df.loc[~imdb_df['cast'].isna(), 'cast'] = imdb_df.loc[~imdb_df['cast'].isna(), 'cast'].apply(convert_string_to_list)
imdb_df.loc[~imdb_df['crew'].isna(), 'crew'] = imdb_df.loc[~imdb_df['crew'].isna(), 'crew'].apply(convert_string_to_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
#check on genre
imdb_df.loc[0,'genres']
# Out:
# [{'id': 35, 'name': 'Comedy'}]

# %%
#check on cast
imdb_df.loc[0,'cast']
# Out:
# [{'cast_id': 4,
#   'character': 'Lou',
#   'credit_id': '52fe4ee7c3a36847f82afae7',
#   'gender': 2,
#   'id': 52997,
#   'name': 'Rob Corddry',
#   'order': 0,
#   'profile_path': '/k2zJL0V1nEZuFT08xUdOd3ucfXz.jpg'},
#  {'cast_id': 5,
#   'character': 'Nick',
#   'credit_id': '52fe4ee7c3a36847f82afaeb',
#   'gender': 2,
#   'id': 64342,
#   'name': 'Craig Robinson',
#   'order': 1,
#   'profile_path': '/tVaRMkJXOEVhYxtnnFuhqW0Rjzz.jpg'},
#  {'cast_id': 6,
#   'character': 'Jacob',
#   'credit_id': '52fe4ee7c3a36847f82afaef',
#   'gender': 2,
#   'id': 54729,
#   'name': 'Clark Duke',
#   'order': 2,
#   'profile_path': '/oNzK0umwm5Wn0wyEbOy6TVJCSBn.jpg'},
#  {'cast_id': 7,
#   'character': 'Adam Jr.',
#   'credit_id': '52fe4ee7c3a36847f82afaf3',
#   'gender': 2,
#   'id': 36801,
#   'name': 'Adam Scott',
#   'order': 3,
#   'profile_path': '/5gb65xz8bzd42yjMAl4zwo4cvKw.jpg'},
#  {'cast_id': 8,
#   'character': 'Hot Tub Repairman',
#   'credit_id': '52fe4ee7c3a36847f82afaf7',
# ...

# %%
#check on crew
imdb_df.loc[0,'crew']
# Out:
# [{'credit_id': '59ac067c92514107af02c8c8',
#   'department': 'Directing',
#   'gender': 0,
#   'id': 1449071,
#   'job': 'First Assistant Director',
#   'name': 'Kelly Cantley',
#   'profile_path': None},
#  {'credit_id': '52fe4ee7c3a36847f82afad7',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 3227,
#   'job': 'Director',
#   'name': 'Steve Pink',
#   'profile_path': '/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg'},
#  {'credit_id': '5524ed25c3a3687ded000d88',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Writer',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed2d925141720c001128',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Characters',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed3d92514166c1004a5d',
#   'department': 'Production',
#   'gender': 2,
#   'id': 57822,
#   'job': 'Producer',
# ...

# %%
# Creating a copy of the imdb_df
imdb_df_new = imdb_df.copy()

# %% [markdown]
# #1. Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.

# %%
imdb_df_new.describe()
# Out:
#              budget       revenue
# count  3.000000e+03  3.000000e+03
# mean   2.253133e+07  6.672585e+07
# std    3.702609e+07  1.375323e+08
# min    0.000000e+00  1.000000e+00
# 25%    0.000000e+00  2.379808e+06
# 50%    8.000000e+06  1.680707e+07
# 75%    2.900000e+07  6.891920e+07
# max    3.800000e+08  1.519558e+09

# %%
# Handling invalid observations
# As we can see budget and revenue are extremely low for some observations. We will replace them with the median
imdb_df_new.loc[imdb_df_new['budget']<1000,'budget'] = imdb_df_new.loc[imdb_df_new['budget']>=1000, 'budget'].median()
imdb_df_new.loc[imdb_df_new['revenue']<1000,'revenue'] = imdb_df_new.loc[imdb_df_new['revenue']>=1000, 'revenue'].median()

# %%
imdb_df_new.describe()
# Out:
#              budget       revenue
# count  3.000000e+03  3.000000e+03
# mean   2.708250e+07  6.705811e+07
# std    3.492773e+07  1.373917e+08
# min    2.500000e+03  1.404000e+03
# 25%    1.000000e+07  2.947600e+06
# 50%    1.645000e+07  1.748753e+07
# 75%    2.900000e+07  6.891920e+07
# max    3.800000e+08  1.519558e+09

# %% [markdown]
# # Profit can be calculated as the difference between the revenue and budget

# %%
# Create profit column
imdb_df_new['profit'] = imdb_df_new['revenue'] - imdb_df_new['budget']

# %%
imdb_df_new.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
# Calculate maximum profit
max_profit = imdb_df_new['profit'].max()

# %%
max_profit_movie_df = imdb_df_new[imdb_df_new['profit']==max_profit]

# %%
max_profit_movie_df
# Out:
#          budget                          genres    imdb_id original_language  \
# 1761  190000000  [{'id': 28, 'name': 'Action'}]  tt2820852                en
#
#      original_title                                               cast  \
# 1761      Furious 7  [{'cast_id': 17, 'character': 'Dominic Toretto...
#
#                                                    crew     revenue  \
# 1761  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
#
#           profit
# 1761  1316249360

# %%
# Creating a list of crew members
crew_list = max_profit_movie_df.loc[1761, 'crew']

# %% [markdown]
# # Get the names of directors and producers

# %%
for elem in crew_list:
  if elem['job'] == 'Producer':
    print(f"The Producer of the movie is {elem['name']}")
  if elem['job'] == 'Director':
    print(f"The Director of the movie is {elem['name']}")
# Out:
# The Producer of the movie is Vin Diesel
# The Producer of the movie is Neal H. Moritz
# The Director of the movie is James Wan
# The Producer of the movie is Michael Fottrell
# The Producer of the movie is Brandon Birtell

# %% [markdown]
# #Get name of actors in highest grossing movie

# %%
# Creating a list of cast
cast_list = max_profit_movie_df.loc[1761, 'cast']

# %%
actor_list = []
for elem in cast_list:
  actor_list.append(elem['name'])

# %%
actor_list
# Out:
# ['Vin Diesel',
#  'Paul Walker',
#  'Dwayne Johnson',
#  'Michelle Rodriguez',
#  'Tyrese Gibson',
#  'Ludacris',
#  'Jordana Brewster',
#  'Djimon Hounsou',
#  'Tony Jaa',
#  'Ronda Rousey',
#  'Nathalie Emmanuel',
#  'Kurt Russell',
#  'Jason Statham',
#  'Sung Kang',
#  'Gal Gadot',
#  'Lucas Black',
#  'Elsa Pataky',
#  'Noel Gugliemi',
#  'John Brotherton',
#  'Luke Evans',
#  'Ali Fazal',
#  'Miller Kimsey',
#  'Charlie Kimsey',
#  'Eden Estrella',
#  'Gentry White',
#  'Iggy Azalea',
#  'Jon Lee Brody',
#  'Levy Tran',
#  'Anna Colwell',
#  'Viktor Hernandez',
#  'Steve Coulter',
#  'Robert Pralgo',
#  'Antwan Mills',
#  'J.J. Phillips',
#  'Jorge Ferragut',
#  'Sara Sohn',
#  'Benjamin Blankenship',
#  'D.J. Hapa',
#  'T-Pain',
#  'Brian Mahoney',
#  'Brittney Alger',
#  'Romeo Santos',
#  'Jocelin Donahue',
#  'Stephanie Langston',
#  'Jorge-Luis Pallo',
#  'Tego Calder√≥n',
#  'Nathalie Kelley',
#  'Shad Moss',
#  'Don Omar',
#  'Klement Tinaj',
#  'Caleb Walker',
# ...

# %% [markdown]
# #2. Which language has the highest average ROI (return on investment)?

# %%
imdb_df_new['roi'] = (imdb_df_new['profit']/imdb_df_new['budget'])*100

# %%
imdb_df_new.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
imdb_df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             3000 non-null   int64
#  1   genres             2993 non-null   object
#  2   imdb_id            3000 non-null   object
#  3   original_language  3000 non-null   object
#  4   original_title     3000 non-null   object
#  5   cast               2987 non-null   object
#  6   crew               2984 non-null   object
#  7   revenue            3000 non-null   int64
#  8   profit             3000 non-null   int64
#  9   roi                3000 non-null   float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 234.5+ KB

# %%
# We will group by on original language and calculate mean of ROI
roi_languages_df = imdb_df_new.groupby('original_language')['roi'].mean().reset_index()
roi_languages_df
# Out:
#    original_language           roi
# 0                 ar    -91.807009
# 1                 bn    -96.739429
# 2                 cn     86.002479
# 3                 cs    -99.894267
# 4                 da     24.702661
# 5                 de    510.347257
# 6                 el   5198.013245
# 7                 en    929.987781
# 8                 es    103.433478
# 9                 fa      3.235168
# 10                fi    -30.319235
# 11                fr     51.900020
# 12                he    456.292450
# 13                hi    249.618424
# 14                hu    -95.535384
# 15                id    -41.617578
# 16                it     22.136747
# 17                ja    122.763087
# 18                ko  11277.949295
# 19                ml    370.833333
# 20                mr    193.333333
# 21                nb     18.847943
# 22                nl    -24.142008
# 23                no     24.155275
# 24                pl    395.816987
# 25                pt    -29.291459
# ...

# %%
max_roi_lan = roi_languages_df[roi_languages_df['roi']==roi_languages_df['roi'].max()]['original_language']
max_roi_lan
# Out:
# 18    ko
# Name: original_language, dtype: object

# %%
print(f"The language with the highest average RoI is {max_roi_lan.values}")
# Out:
# The language with the highest average RoI is ['ko']

# %% [markdown]
# #3. Find out the unique genres of movies in this dataset.

# %%
# Considering only those observations in genre which are having non null values
imdb_df_no_na_genres = imdb_df_new[~imdb_df_new['genres'].isna()]

# %%
imdb_df_no_na_genres.shape
# Out:
# (2993, 10)

# %%
imdb_df_no_na_genres.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
#Check 
imdb_df_no_na_genres.iloc[5]['genres']
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 10751, 'name': 'Family'}]

# %%
# As we can see we have multiple genres for some movies

# %%
# Check on method .iterrows()
for index, row in imdb_df_no_na_genres.iloc[0:2].iterrows():
  print(index)
  print(row)
# Out:
# 0
# budget                                                        14000000
# genres                                  [{'id': 35, 'name': 'Comedy'}]
# imdb_id                                                      tt2637294
# original_language                                                   en
# original_title                                  Hot Tub Time Machine 2
# cast                 [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# crew                 [{'credit_id': '59ac067c92514107af02c8c8', 'de...
# revenue                                                       12314651
# profit                                                        -1685349
# roi                                                         -12.038207
# Name: 0, dtype: object
# 1
# budget                                                        40000000
# genres               [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# imdb_id                                                      tt0368933
# ...

# %%
for elem in imdb_df_no_na_genres.iloc[0:2].iterrows():
  print(elem)
# Out:
# (0, budget                                                        14000000
# genres                                  [{'id': 35, 'name': 'Comedy'}]
# imdb_id                                                      tt2637294
# original_language                                                   en
# original_title                                  Hot Tub Time Machine 2
# cast                 [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# crew                 [{'credit_id': '59ac067c92514107af02c8c8', 'de...
# revenue                                                       12314651
# profit                                                        -1685349
# roi                                                         -12.038207
# Name: 0, dtype: object)
# (1, budget                                                        40000000
# genres               [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# imdb_id                                                      tt0368933
# ...

# %%
# As we can see above the method .iterrows creates a tuple in which the first element is the index and second element is row associated with it

# %%
#Create the list of genres
genres_list = []
#Iterate over each observation in the dataframe
for index, row in imdb_df_no_na_genres.iterrows():
  # Identify the list of genres
  genre_list = row['genres']
  #We will iterate over list of dictionaries
  for elem in genre_list:
    genres_list.append(elem['name'])

# %%
# We will use set function to get unique set of genres
set(genres_list)
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Foreign',
#  'History',
#  'Horror',
#  'Music',
#  'Mystery',
#  'Romance',
#  'Science Fiction',
#  'TV Movie',
#  'Thriller',
#  'War',
#  'Western'}

# %% [markdown]
# # 4. Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI?

# %%
# Create a dataframe in which we have no null observations for the column crew
imdb_df_no_na_crew = imdb_df_new[~imdb_df_new['crew'].isna()]

# %%
imdb_df_no_na_crew.iloc[0]['crew']
# Out:
# [{'credit_id': '59ac067c92514107af02c8c8',
#   'department': 'Directing',
#   'gender': 0,
#   'id': 1449071,
#   'job': 'First Assistant Director',
#   'name': 'Kelly Cantley',
#   'profile_path': None},
#  {'credit_id': '52fe4ee7c3a36847f82afad7',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 3227,
#   'job': 'Director',
#   'name': 'Steve Pink',
#   'profile_path': '/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg'},
#  {'credit_id': '5524ed25c3a3687ded000d88',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Writer',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed2d925141720c001128',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Characters',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed3d92514166c1004a5d',
#   'department': 'Production',
#   'gender': 2,
#   'id': 57822,
#   'job': 'Producer',
# ...

# %%
# Creating a function which returns the list of producer for each movie
def get_producers_and_directors(crew_list):
  try:

    producer_list = []
    director_list = []
    for elem in crew_list:
      if elem['job']=='Producer':
        producer_list.append(elem['name'])
      if elem['job']=='Director':
        director_list.append(elem['name'])
    return producer_list,director_list
  except:
    return [],[]

# %%
#Check
get_producers_and_directors(imdb_df_no_na_crew.loc[600,'crew'])
# Out:
# (['Jerry Bruckheimer', 'Don Simpson'], ['Tony Scott'])

# %%
# Creating two new columns Producers and Directors
imdb_df_new[['Producers', 'Directors']] = imdb_df_new.apply(lambda row: get_producers_and_directors(row['crew']), axis=1, result_type='expand')

# %%
imdb_df_new.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
movie_prod_dir_df = imdb_df_new[['original_title', 'Producers', 'Directors']]

# %%
movie_prod_dir_df.head()
# Out:
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                            Producers          Directors
# 0                                     [Andrew Panay]       [Steve Pink]
# 1  [Whitney Houston, Mario Iscovich, Debra Martin...   [Garry Marshall]
# 2  [David Lancaster, Michel Litvak, Jason Blum, H...  [Damien Chazelle]
# 3                                      [Sujoy Ghosh]      [Sujoy Ghosh]
# 4                                                 []   [Jong-seok Yoon]

# %%
movie_prod_roi_df = imdb_df_new[['original_title', 'Producers', 'roi']]

# %%
movie_prod_roi_df.head()
# Out:
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                            Producers          roi
# 0                                     [Andrew Panay]   -12.038207
# 1  [Whitney Houston, Mario Iscovich, Debra Martin...   137.873588
# 2  [David Lancaster, Michel Litvak, Jason Blum, H...   296.727273
# 3                                      [Sujoy Ghosh]  1233.333333
# 4                                                 []   -76.146079

# %%
movie_prod_roi_df.head()
# Out:
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                            Producers          roi
# 0                                     [Andrew Panay]   -12.038207
# 1  [Whitney Houston, Mario Iscovich, Debra Martin...   137.873588
# 2  [David Lancaster, Michel Litvak, Jason Blum, H...   296.727273
# 3                                      [Sujoy Ghosh]  1233.333333
# 4                                                 []   -76.146079

# %%
full_producer_list = []
for elem in movie_prod_roi_df['Producers']:
  full_producer_list = full_producer_list + elem
unique_producer_set = set(full_producer_list)
unique_producer_list = list(unique_producer_set)
producer_df = pd.DataFrame(unique_producer_list, columns = ['Producer Name'])

# %%
producer_df.head()
# Out:
#      Producer Name
# 0  K.C. Hodenfield
# 1  Lawrence Kasdan
# 2      Ben Stassen
# 3      Tom Pollock
# 4      Eric McLeod

# %%
producer_df_copy = producer_df.copy()
producer_df_copy.head()
# Out:
#      Producer Name
# 0  K.C. Hodenfield
# 1  Lawrence Kasdan
# 2      Ben Stassen
# 3      Tom Pollock
# 4      Eric McLeod

# %%
# Function to create
def get_movie_list_for_producer(producer_name):
  try:

    producer_movie_list = []
    for index,row in movie_prod_roi_df.iterrows():
      for elem in row['Producers']:
        if producer_name in elem:
          producer_movie_list.append(row['original_title'])
    return producer_movie_list
  except:
    return []

# %%
producer_df_copy['movies'] = producer_df_copy['Producer Name'].apply(get_movie_list_for_producer)

# %%
producer_df_copy.head()
# Out:
#      Producer Name                                             movies
# 0  K.C. Hodenfield  [The Chronicles of Narnia: The Lion, the Witch...
# 1  Lawrence Kasdan                      [Dreamcatcher, The Bodyguard]
# 2      Ben Stassen                                  [Robinson Crusoe]
# 3      Tom Pollock                             [Hitchcock, Disturbia]
# 4      Eric McLeod         [Pirates of the Caribbean: At World's End]

# %%
producer_df_copy.set_index('Producer Name', inplace=True)

# %%
producer_df_copy.head()
# Out:
#                                                             movies
# Producer Name
# K.C. Hodenfield  [The Chronicles of Narnia: The Lion, the Witch...
# Lawrence Kasdan                      [Dreamcatcher, The Bodyguard]
# Ben Stassen                                      [Robinson Crusoe]
# Tom Pollock                                 [Hitchcock, Disturbia]
# Eric McLeod             [Pirates of the Caribbean: At World's End]

# %%
#Check
producer_df_copy.loc['Vin Diesel']['movies']
# Out:
# ['The Last Witch Hunter', 'A Man Apart', 'Furious 7', 'Fast & Furious']

# %%
movie_prod_roi_df.set_index('original_title', inplace=True)

# %%
def get_avg_roi(movie_list):
  sum_roi = 0
  for elem in movie_list:
    sum_roi = sum_roi + (movie_prod_roi_df.loc[elem]['roi'])
    avg_roi = (sum_roi)/len(movie_list)
  return round(avg_roi,2)

# %%
#Check
get_avg_roi(producer_df_copy.loc['Vin Diesel']['movies'])
# Out:
# 276.62

# %%
producer_df_copy['AVG ROI'] = producer_df_copy['movies'].apply(get_avg_roi)

# %%
producer_df_copy
# Out:
#                                                                    movies  \
# Producer Name
# K.C. Hodenfield         [The Chronicles of Narnia: The Lion, the Witch...
# Lawrence Kasdan                             [Dreamcatcher, The Bodyguard]
# Ben Stassen                                             [Robinson Crusoe]
# Tom Pollock                                        [Hitchcock, Disturbia]
# Eric McLeod                    [Pirates of the Caribbean: At World's End]
# ...                                                                   ...
# Emile Sherman                                        [Tracks, Mr. Holmes]
# Jackie Marcus Schaffer                                        [Disturbia]
# Bill Walsh                                                 [Mary Poppins]
# Takafumi Watanabe                                               [サマーウォーズ]
# Brent Kunkle                                                 [Stake Land]
#
#                         AVG ROI
# Producer Name
# ...

# %%
producer_df_copy['AVG ROI'] = pd.to_numeric(producer_df_copy['AVG ROI'], errors='coerce')

# %%
producer_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3546 entries, K.C. Hodenfield to Brent Kunkle
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movies   3546 non-null   object
#  1   AVG ROI  3438 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 212.1+ KB

# %%
producer_df_copy.sort_values('AVG ROI', ascending= False)[0:3]
# Out:
#                                   movies     AVG ROI
# Producer Name
# Amir Zbeda         [Paranormal Activity]  1288938.67
# Gregg Hale     [The Blair Witch Project]   413233.33
# Robin Cowie    [The Blair Witch Project]   413233.33

# %% [markdown]
# # 5. Which actor has acted in the most number of movies? Deep dive into the movies and genres corresponding to this actor.

# %%
imdb_df_no_na_cast = imdb_df_new[~imdb_df_new['cast'].isna()]

# %%
imdb_df_no_na_cast['cast'][6]
# Out:
# [{'cast_id': 23,
#   'character': 'Clyde',
#   'credit_id': '52fe4981c3a368484e12ee17',
#   'gender': 2,
#   'id': 47296,
#   'name': 'Jeffrey Dean Morgan',
#   'order': 0,
#   'profile_path': '/6ors2HGy8UdXm8kBx6on0HwRHB5.jpg'},
#  {'cast_id': 31,
#   'character': 'Em',
#   'credit_id': '52fe4981c3a368484e12ee39',
#   'gender': 0,
#   'id': 94482,
#   'name': 'Natasha Calis',
#   'order': 1,
#   'profile_path': '/i6txLt6FyZW7G7thV5AmTeHtWrC.jpg'},
#  {'cast_id': 37,
#   'character': 'Hannah',
#   'credit_id': '545658a50e0a2648d60074e0',
#   'gender': 1,
#   'id': 52869,
#   'name': 'Madison Davenport',
#   'order': 2,
#   'profile_path': '/AjqfjA4cVbLgVg2IZxUwBaGISGZ.jpg'},
#  {'cast_id': 24,
#   'character': 'Stephanie',
#   'credit_id': '52fe4981c3a368484e12ee1b',
#   'gender': 1,
#   'id': 26467,
#   'name': 'Kyra Sedgwick',
#   'order': 3,
#   'profile_path': '/udLKlspMdXSC9LMdhygL5rcJ4XI.jpg'},
#  {'cast_id': 28,
#   'character': 'Russell',
# ...

# %%
full_actor_list = []
for elem in imdb_df_no_na_cast['cast']:
  for i in elem:
    full_actor_list.append(i['name'])

# %%
len(full_actor_list)
# Out:
# 61811

# %%
actor_df = pd.DataFrame(full_actor_list, columns = ['actor_name'])

# %%
actor_df
# Out:
#                     actor_name
# 0                  Rob Corddry
# 1               Craig Robinson
# 2                   Clark Duke
# 3                   Adam Scott
# 4                  Chevy Chase
# ...                        ...
# 61806               Jack Erdie
# 61807              Steve Blass
# 61808            Derek Burnell
# 61809  Tiffany Sander McKenzie
# 61810         Joanna Theobalds
#
# [61811 rows x 1 columns]

# %%
actor_volume = actor_df['actor_name'].value_counts()

# %%
actor_volume[0:3]
# Out:
# Robert De Niro       30
# Samuel L. Jackson    30
# Morgan Freeman       27
# Name: actor_name, dtype: int64

# %%
# Creating a function which returns the list of actor
def get_actors(cast_list):
  try:

    actor_list = []
    for elem in cast_list:
      actor_list.append(elem['name'])
      
      
    return actor_list
  except:
    return []

# %%
imdb_df_no_na_cast.loc[9,'cast']
# Out:
# [{'cast_id': 24,
#   'character': 'Jonathan Steinbloom',
#   'credit_id': '54165a5dc3a3684d06003f19',
#   'gender': 2,
#   'id': 12438,
#   'name': 'Bob Balaban',
#   'order': 0,
#   'profile_path': '/3g7IKz8ycv0opDxmpoBxsQkUslU.jpg'},
#  {'cast_id': 5,
#   'character': 'Alan Barrows',
#   'credit_id': '52fe45609251416c75054595',
#   'gender': 2,
#   'id': 13524,
#   'name': 'Christopher Guest',
#   'order': 1,
#   'profile_path': '/fhEQq0q2aR2sh4HU824xunoyAce.jpg'},
#  {'cast_id': 9,
#   'character': 'Terry Bohner',
#   'credit_id': '52fe45609251416c750545a5',
#   'gender': 2,
#   'id': 8265,
#   'name': 'John Michael Higgins',
#   'order': 2,
#   'profile_path': '/91ANQZVoG0Xg2vVnqIhouHiNc4J.jpg'},
#  {'cast_id': 4,
#   'character': 'Mitch Cohen',
#   'credit_id': '52fe45609251416c75054591',
#   'gender': 2,
#   'id': 26510,
#   'name': 'Eugene Levy',
#   'order': 3,
#   'profile_path': '/69IBiDjU1gSqtrcGOA7PA7aEYsc.jpg'},
#  {'cast_id': 6,
#   'character': 'Laurie Bohner',
# ...

# %%
#Check
get_actors(imdb_df_no_na_cast.loc[11,'cast'])
# Out:
# ['Robert Carradine',
#  'Curtis Armstrong',
#  'Larry B. Scott',
#  'Timothy Busfield',
#  'Courtney Thorne-Smith',
#  'Andrew Cassese',
#  'Donald Gibb',
#  'Bradley Whitford',
#  'Ed Lauter',
#  'Barry Sobel',
#  'Anthony Edwards',
#  'James Hong',
#  'Ruben Rabasa',
#  'James Cromwell']

# %%
# Creating one new column Actors
imdb_df_new['Actors'] = imdb_df_new['cast'].apply(get_actors)
imdb_df_new.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
movie_actor_df = imdb_df_new[['original_title', 'Actors']]
movie_actor_df
# Out:
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                  Actors
# 0     [Rob Corddry, Craig Robinson, Clark Duke, Adam...
# 1     [Anne Hathaway, Julie Andrews, H√©ctor Elizond...
# 2     [Miles Teller, J.K. Simmons, Melissa Benoist, ...
# 3     [Vidya Balan, Nawazuddin Siddiqui, Parambrata ...
# 4     [Kim Kang-woo, Jo Jae-hyeon, Park Si-yeon, Kim...
# ...                                                 ...
# ...

# %%
full_actor_list = []
for elem in movie_actor_df['Actors']:
  full_actor_list = full_actor_list + elem
unique_actor_set = set(full_actor_list)
unique_actor_list = list(unique_actor_set)
actor_df = pd.DataFrame(unique_actor_list, columns = ['Actor Name'])

# %%
actor_df
# Out:
#              Actor Name
# 0         Baxter Harris
# 1        Alexis Toutant
# 2        Hadewych Minis
# 3         Bill Phillips
# 4       Jean-Luc Julien
# ...                 ...
# 38583    Kate Lyn Sheil
# 38584    Lindsey Ginter
# 38585         Owen Best
# 38586  Kristyn Abbadini
# 38587      Valley Keene
#
# [38588 rows x 1 columns]

# %%
def get_movie_list_for_actor(actor_name):
  try:

    actor_movie_list = []
    for index,row in movie_actor_df.iterrows():
      for elem in row['Actors']:
        if actor_name in elem:
          actor_movie_list.append(row['original_title'])
    return actor_movie_list
  except:
    return []

# %%
#Check
get_movie_list_for_actor('Vin Diesel')
# Out:
# ['The Last Witch Hunter',
#  'The Fast and the Furious: Tokyo Drift',
#  'The Fast and the Furious',
#  'The Pacifier',
#  'Find Me Guilty',
#  'A Man Apart',
#  'Furious 7',
#  'Guardians of the Galaxy',
#  'Guardians of the Galaxy Vol. 2',
#  'Fast & Furious',
#  'Knockaround Guys']

# %%
actor_df_copy = actor_df.copy()

# %%
actor_df_copy['movies'] = actor_df_copy['Actor Name'].apply(get_movie_list_for_actor)

# %%
actor_df_copy
# Out:
#              Actor Name                               movies
# 0         Baxter Harris       [Scent of a Woman, Species II]
# 1        Alexis Toutant                     [Into the Storm]
# 2        Hadewych Minis                       [Toni Erdmann]
# 3         Bill Phillips                        [Wall Street]
# 4       Jean-Luc Julien                           [Big Game]
# ...                 ...                                  ...
# 38583    Kate Lyn Sheil  [V/H/S, The Sacrament, You're Next]
# 38584    Lindsey Ginter                           [S.W.A.T.]
# 38585         Owen Best                       [TRON: Legacy]
# 38586  Kristyn Abbadini                    [Starsky & Hutch]
# 38587      Valley Keene                          [Spartacus]
#
# [38588 rows x 2 columns]

# %%
actor_df_copy.set_index('Actor Name', inplace=True)

# %%
actor_df_copy.head()
# Out:
#                                          movies
# Actor Name
# Baxter Harris    [Scent of a Woman, Species II]
# Alexis Toutant                 [Into the Storm]
# Hadewych Minis                   [Toni Erdmann]
# Bill Phillips                     [Wall Street]
# Jean-Luc Julien                      [Big Game]

# %% [markdown]
# # Top three actors
# Robert De Niro
# Samuel L. Jackson
# Morgan Freeman

# %%
# Movies done by Robert De Niro
actor_df_copy.loc['Robert De Niro','movies']
# Out:
# ['This Boy’s Life',
#  'What Just Happened',
#  'Mad Dog and Glory',
#  'The Good Shepherd',
#  'Lenny Bruce: Swear to Tell the Truth',
#  'Red Lights',
#  'Falling in Love',
#  'Wag the Dog',
#  'Meet the Parents',
#  "Marvin's Room",
#  'Sleepers',
#  'The Fan',
#  'The Family',
#  'Stone',
#  'Being Flynn',
#  'Righteous Kill',
#  'American Hustle',
#  'Jackie Brown',
#  'Raging Bull',
#  'Angel Heart',
#  'Joy',
#  'The Deer Hunter',
#  'Stanley & Iris',
#  'Machete',
#  'Mean Streets',
#  'Men of Honor',
#  'Analyze This',
#  'The Bag Man',
#  'The Score',
#  'Backdraft']

# %%
# Movies done by Samuel L. Jackson
actor_df_copy.loc['Samuel L. Jackson','movies']
# Out:
# ['Changing Lanes',
#  'The Hateful Eight',
#  'Coming to America',
#  'Star Wars: Episode III - Revenge of the Sith',
#  'Meeting Evil',
#  'The Avengers',
#  'Jumper',
#  'Shaft',
#  'Snakes on a Plane',
#  'The Man',
#  'RoboCop',
#  'Jurassic Park',
#  'Cell',
#  'Star Wars: Episode II - Attack of the Clones',
#  'Eddie Murphy Raw',
#  'Captain America: The Winter Soldier',
#  'Jackie Brown',
#  'African Cats',
#  'Big Game',
#  'Black Snake Moan',
#  'Sea of Love',
#  'Deep Blue Sea',
#  'Basic',
#  'The Incredibles',
#  'Avengers: Age of Ultron',
#  'Out of Sight',
#  'Patriot Games',
#  'S.W.A.T.',
#  'Freedomland',
#  'The Long Kiss Goodnight']

# %%
# Movies done by Morgan Freeman
actor_df_copy.loc['Morgan Freeman','movies']
# Out:
# ['Outbreak',
#  '5 Flights Up',
#  'Now You See Me',
#  'Kiss the Girls',
#  'Born to Be Wild',
#  'Batman Begins',
#  'Along Came a Spider',
#  'Clean and Sober',
#  'Glory',
#  'High Crimes',
#  'The Big Bounce',
#  'The Dark Knight',
#  'Johnny Handsome',
#  'Evan Almighty',
#  'The Shawshank Redemption',
#  'Feast of Love',
#  'Olympus Has Fallen',
#  'Dreamcatcher',
#  'Chain Reaction',
#  'London Has Fallen',
#  'Robin Hood: Prince of Thieves',
#  'The Bonfire of the Vanities',
#  '10 Items or Less',
#  'Lucky Number Slevin',
#  'Dolphin Tale',
#  'Ben-Hur',
#  'Ted 2']

# %%
imdb_df_new['genres']
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 3000, dtype: object

# %%
# Creating a function which returns the genres of a movie
def get_genres(genre_list):
  try:

    gen_list = []
    for elem in genre_list:
      gen_list.append(elem['name'])
      
      
    return gen_list
  except:
    return []

# %%
imdb_df_new['Genres'] = imdb_df_new['genres'].apply(get_genres)

# %%
imdb_df_new.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
movie_genre_df = imdb_df_new[['original_title', 'Genres']]

# %%
movie_genre_df
# Out:
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                   Genres
# 0                               [Comedy]
# 1       [Comedy, Drama, Family, Romance]
# 2                                [Drama]
# 3                      [Thriller, Drama]
# 4                     [Action, Thriller]
# ...                                  ...
# 2995                   [Comedy, Romance]
# 2996                      [Drama, Music]
# ...

# %%
movie_genre_df.set_index('original_title', inplace=True)

# %% [markdown]
# # Genres of movies done by Robert De Niro

# %%
robert_df = pd.DataFrame(actor_df_copy.loc['Robert De Niro','movies'], columns = ['movies'])

# %%
def get_genre_from_movie(movie_name):
  gen_lst = movie_genre_df.loc[movie_name,'Genres']
  return gen_lst

# %%
robert_df['genres'] = robert_df['movies'].apply(get_genre_from_movie)

# %%
robert_df
# Out:
#                                   movies  \
# 0                        This Boy’s Life
# 1                     What Just Happened
# 2                      Mad Dog and Glory
# 3                      The Good Shepherd
# 4   Lenny Bruce: Swear to Tell the Truth
# 5                             Red Lights
# 6                        Falling in Love
# 7                            Wag the Dog
# 8                       Meet the Parents
# 9                          Marvin's Room
# 10                              Sleepers
# 11                               The Fan
# 12                            The Family
# 13                                 Stone
# 14                           Being Flynn
# 15                        Righteous Kill
# 16                       American Hustle
# 17                          Jackie Brown
# 18                           Raging Bull
# 19                           Angel Heart
# 20                                   Joy
# 21                       The Deer Hunter
# ...

# %% [markdown]
# #Genres of movies done by Samuel L. Jackson

# %%
samuel_df = pd.DataFrame(actor_df_copy.loc['Samuel L. Jackson','movies'], columns = ['movies'])

# %%
samuel_df['genres'] = samuel_df['movies'].apply(get_genre_from_movie)

# %%
samuel_df
# Out:
#                                           movies  \
# 0                                 Changing Lanes
# 1                              The Hateful Eight
# 2                              Coming to America
# 3   Star Wars: Episode III - Revenge of the Sith
# 4                                   Meeting Evil
# 5                                   The Avengers
# 6                                         Jumper
# 7                                          Shaft
# 8                              Snakes on a Plane
# 9                                        The Man
# 10                                       RoboCop
# 11                                 Jurassic Park
# 12                                          Cell
# 13  Star Wars: Episode II - Attack of the Clones
# 14                              Eddie Murphy Raw
# 15           Captain America: The Winter Soldier
# 16                                  Jackie Brown
# 17                                  African Cats
# ...

# %% [markdown]
# #Genres of movies done by Morgan Freeman

# %%
morgan_df = pd.DataFrame(actor_df_copy.loc['Morgan Freeman','movies'], columns = ['movies'])

# %%
morgan_df['genres'] = morgan_df['movies'].apply(get_genre_from_movie)

# %%
morgan_df
# Out:
#                            movies  \
# 0                        Outbreak
# 1                    5 Flights Up
# 2                  Now You See Me
# 3                  Kiss the Girls
# 4                 Born to Be Wild
# 5                   Batman Begins
# 6             Along Came a Spider
# 7                 Clean and Sober
# 8                           Glory
# 9                     High Crimes
# 10                 The Big Bounce
# 11                The Dark Knight
# 12                Johnny Handsome
# 13                  Evan Almighty
# 14       The Shawshank Redemption
# 15                  Feast of Love
# 16             Olympus Has Fallen
# 17                   Dreamcatcher
# 18                 Chain Reaction
# 19              London Has Fallen
# 20  Robin Hood: Prince of Thieves
# 21    The Bonfire of the Vanities
# 22               10 Items or Less
# 23            Lucky Number Slevin
# 24                   Dolphin Tale
# 25                        Ben-Hur
# ...
